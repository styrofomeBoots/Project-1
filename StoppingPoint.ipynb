# %%
import pandas as pd

death05_15 = pd.read_csv("C:/Users/sethn/Desktop/FreshStartDeath/sample5death05_15.csv", low_memory=False)

# %%
death05_15.dtypes
# Out:
# Unnamed: 0                               int64
# 113_cause_recode                         int64
# 130_infant_cause_recode                float64
# 358_cause_recode                       float64
# 39_cause_recode                        float64
# Unnamed: 0.1                             int64
# Unnamed: 0.1.1                         float64
# activity_code                          float64
# age_recode_12                          float64
# age_recode_27                          float64
# age_recode_52                          float64
# autopsy                                 object
# current_data_year                        int64
# day_of_week_of_death                     int64
# detail_age                               int64
# detail_age_type                        float64
# education_2003_revision                float64
# hispanic_origin                        float64
# hispanic_originrace_recode               int64
# icd_code_10th_revision                  object
# ...

# %%
# Distribution of causes of death
# Correlation betweeen the general population and causes

death05_15["marital_status"].value_counts()
# Out:
# M    519071
# W    489132
# D    192018
# S    171745
# U     14067
# Name: marital_status, dtype: int64

# %%
death05_15.head()
# Out:
#    Unnamed: 0  113_cause_recode  130_infant_cause_recode  358_cause_recode  \
# 0           0                67                      NaN               NaN
# 1           1                95                      NaN               NaN
# 2           2                70                      NaN               NaN
# 3           3                68                      NaN               NaN
# 4           4                24                      NaN               NaN
#
#    39_cause_recode  Unnamed: 0.1  Unnamed: 0.1.1  activity_code  \
# 0              NaN      12710949      12710949.0            NaN
# 1              NaN       4686059       4686059.0            NaN
# 2              NaN       6762380       6762380.0            NaN
# 3              NaN      12325960      12325960.0            NaN
# 4              NaN        491263        491263.0            NaN
#
#    age_recode_12  age_recode_27 ...  injury_at_work manner_of_death  \
# ...

# %%
import matplotlib.pyplot as plt

plt.figure()
death05_15.groupby(["current_data_year", "marital_status"])["marital_status"].count().plot()
plt.show()

# %%
death05_15.groupby(["current_data_year", "marital_status"])["activity_code"].count().reset_index()
# Out:
#     current_data_year marital_status  activity_code
# 0                2005              D           1366
# 1                2005              M           2904
# 2                2005              S           3003
# 3                2005              U             83
# 4                2005              W           1078
# 5                2006              D           1504
# 6                2006              M           2823
# 7                2006              S           3262
# 8                2006              U             97
# 9                2006              W           1065
# 10               2007              D           1569
# 11               2007              M           2946
# 12               2007              S           3348
# 13               2007              U             84
# 14               2007              W           1091
# 15               2008              D           1570
# 16               2008              M           2840
# ...

# %%
YearGroup = death05_15.groupby("current_data_year")

# %%
div = YearGroup["marital_status"].count()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b205c1fd0ea3> in <module>
# ----> 1 complete.dtypes
#
# NameError: name 'complete' is not defined

# %%
dummies = pd.get_dummies(death05_15["marital_status"])

# %%
complete = death05_15.join(dummies)

# %%
YearGroup = complete.groupby("current_data_year")

# %%
div = YearGroup["D"].sum()
wid = YearGroup["W"].sum()
mar = YearGroup["M"].sum()
sin = YearGroup["S"].sum()
unm = YearGroup["U"].sum()

# %%
DeathByMarStat = pd.DataFrame({"Divorced": div,
                             "Widowed": wid,
                             "Married": mar,
                             "Single": sin,
                             "Unmarried": unm})
DeathByMarStat

# %%
DeathByMarStat.plot(kind="Line", use_index=True, y=["Divorced", "Widowed", "Married", "Single", "Unmarried"])

# %%
import json

import json
import pandas as pd

jsonfile = "C:/Users/sethn/Desktop/ALLPRIORDEATHWORK/mortality/2015_codes.json"
json_data=open(jsonfile).read()
data = json.loads(json_data)

df = pd.DataFrame.from_dict(data['113_cause_recode'], orient='index')

df = df.rename(columns={0:"113_Cause"})
df = df.reset_index()
df = df.rename(columns={"index":"Code"})
df

# %%
complete["113_cause_recode"].value_counts()

# %%
df = complete.groupby(["current_data_year", "age_recode_12"])
dfdataframe = pd.DataFrame(df)
dfdataframe
